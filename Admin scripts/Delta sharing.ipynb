# %%
# %sql
CREATE SHARE northwind_share;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>info_name</th><th>info_value</th></tr></thead><tbody><tr><td>share_name</td><td>northwind_share</td></tr><tr><td>owner</td><td>hubarmando04_gmail.com#ext#@hubarmando04gmail.onmicrosoft.com</td></tr><tr><td>created_at</td><td>2025-12-11 20:38:47.935</td></tr><tr><td>created_by</td><td>hubarmando04_gmail.com#ext#@hubarmando04gmail.onmicrosoft.com</td></tr><tr><td>updated_at</td><td>2025-12-11 20:38:47.935</td></tr><tr><td>updated_by</td><td>hubarmando04_gmail.com#ext#@hubarmando04gmail.onmicrosoft.com</td></tr><tr><td>comment</td><td></td></tr></tbody></table></div>

# %%
# %sql
ALTER SHARE northwind_share ADD TABLE principal.golden.fact_sales;
ALTER SHARE northwind_share ADD TABLE principal.golden.dim_products;
ALTER SHARE northwind_share ADD TABLE principal.golden.dim_customers;
ALTER SHARE northwind_share ADD TABLE principal.golden.dim_dates;
ALTER SHARE northwind_share ADD TABLE principal.golden.dim_country;

# %%
# %sql
CREATE RECIPIENT powerbi_recipient;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
GRANT SELECT ON SHARE northwind_share TO RECIPIENT powerbi_recipient;

# %%
# %sql
SHOW SHARE northwind_share
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>share</th><th>created_at</th><th>created_by</th><th>comment</th></tr></thead><tbody><tr><td>northwind_share</td><td>2025-12-11T20:38:47.935Z</td><td>hubarmando04_gmail.com#ext#@hubarmando04gmail.onmicrosoft.com</td><td>null</td></tr></tbody></table></div>
