# %% [markdown]
# ### Permisos revoque

# %%
# %sql
REVOKE ALL PRIVILEGES ON CATALOG principal from `Analistas`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  principal.bronze from `Analistas`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  principal.silver from `Analistas`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  principal.golden from `Analistas`;

# %%
# %sql
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-raw` from `Analistas`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-bronze` from `Analistas`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-silver` from `Analistas`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-golden` from `Analistas`;
