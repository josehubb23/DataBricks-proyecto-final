# %% [markdown]
# ### Permisos grants

# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG principal TO `Analistas`;
GRANT CREATE, USE SCHEMA ON SCHEMA  principal.bronze to `Analistas`;
GRANT CREATE, USE SCHEMA ON SCHEMA  principal.silver to `Analistas`;
GRANT CREATE, USE SCHEMA ON SCHEMA  principal.golden to `Analistas`;

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-raw` to `Analistas`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-bronze` to `Analistas`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-silver` to `Analistas`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `extl-golden` to `Analistas`;
